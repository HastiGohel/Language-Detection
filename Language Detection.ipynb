# %%
pip install langdetect
# Out:
# ...
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      -------------------------------------- 981.5/981.5 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993251 sha256=69590eb53a5a4bba43b5fe90be50b179567a32fb4df52f36591099168a8ad7ef
#   Stored in directory: c:\users\hasti gohel\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langdetect pycountry
# Out:
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------------- -------------------------- 2.1/6.3 MB 23.5 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 20.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 17.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv('language.csv')
df.head()
# Out:
#                    Sentence
# 0       Hello, how are you?
# 1      नमस्ते, आप कैसे हैं?
# 2        Hola, ¿cómo estás?
# 3  Bonjour, comment ça va ?
# 4                   你好，你好吗？

# %%
def detect_language_name(text):
    try:
        lang_code = detect(text)
        lang_name = pycountry.languages.get(alpha_2=lang_code)
        return lang_name.name if lang_name else "Unknown"
    except:
        return "Unknown", "Unknown"

df["Language_Name"] = df["Sentence"].apply(lambda x: pd.Series(detect_language_name(x)))

df
# Out:
#                      Sentence Detected_Language Lang_Code Language_Name
# 0         Hello, how are you?                en        en       English
# 1        नमस्ते, आप कैसे हैं?                hi        hi         Hindi
# 2          Hola, ¿cómo estás?                es        es       Spanish
# 3    Bonjour, comment ça va ?                fr        fr        French
# 4                     你好，你好吗？             zh-cn     zh-cn       Unknown
# 5     Hallo, wie geht es dir?                de        de     Afrikaans
# 6            Ciao, come stai?                pt        pt    Portuguese
# 7           Привет, как дела?                mk        mk    Macedonian
# 8               こんにちは、お元気ですか？                ja        ja      Japanese
# 9          Merhaba, nasılsın?                tr        tr       Turkish
# 10          Sawubona, unjani?                sw        sw      Croatian
# 11          Salve, quid agis?                ca        ca       Catalan
# ...
